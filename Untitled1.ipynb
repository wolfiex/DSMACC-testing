# %% [markdown]
# ## Comparison
#
# For explanation on metrics (visual) go to:
# https://cs.hse.ru/data/2015/05/14/1098547089/4._Centrality_Metrics.pdf

# %%
import pandas as pd
from matplotlib.pyplot import *

# %%
df=pd.read_csv('centrality.csv')
print df.head()
# Out:
#   Unnamed: 0      Flux    FluxIn   FluxOut     Closeness  EigenCentrality  \
# 0     CH3NO3  0.000139  0.000357  0.000004  9.709534e-07         0.000030
# 1     C2H5O2  0.027765  0.039644  0.020361  9.702916e-07         0.000000
# 2      CH3OH  0.001586  0.002802  0.000829  9.032640e-07         0.000235
# 3        PAN  0.741658  0.964501  0.602769  6.486455e-07         1.000000
# 4    IPROPOL  0.000001  0.000002  0.000001  9.503258e-07         0.000000
#
#    PageRank  Betweenness  Authorities          Hubs
# 0  0.036067     0.256757     0.101733  3.593448e-10
# 1  0.090963     0.959459     0.056458  0.000000e+00
# 2  0.041202     0.000000     0.101733  7.782253e-08
# 3  0.300982     0.000000     0.027963  3.283264e-06
# 4  0.035323     0.270270     0.000000  1.775666e-18

# %%
print df.columns
df.index
d = [i[:2]+i[-3:] for i in df.columns]
d[0]='Names'
df.columns=d
df.index=df.Names
df.columns
# Out:
# Index([u'Unnamed: 0', u'Flux', u'FluxIn', u'FluxOut', u'Closeness',
#        u'EigenCentrality', u'PageRank', u'Betweenness', u'Authorities',
#        u'Hubs'],
#       dtype='object')
# Index([u'Names', u'Fllux', u'FlxIn', u'FlOut', u'Cless', u'Eiity', u'Paank',
#        u'Beess', u'Auies', u'Huubs'],
#       dtype='object')

# %%
df.plot(x='Names',subplots=True)
show()

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(df, alpha=0.2, figsize=(6, 6), diagonal='kde')
show()

# %%
from pandas.plotting import andrews_curves
andrews_curves(df,'Names')
legend(loc='center left', bbox_to_anchor=(1.0, 0.5),ncol = 4)
show()
'''Andrews curves allow one to plot multivariate data as a large number of curves that are created
using the attributes of samples as coefficients for Fourier series. By coloring these curves 
differently for each class it is possible to visualize data clustering. Curves belonging to samples
of the same class will usually be closer together and form larger structures.'''''
# Out:
# 'Andrews curves allow one to plot multivariate data as a large number of curves that are created\nusing the attributes of samples as coefficients for Fourier series. By coloring these curves \ndifferently for each class it is possible to visualize data clustering. Curves belonging to samples\nof the same class will usually be closer together and form larger structures.'

# %%
from pandas.plotting import radviz
radviz(df, 'Names')
legend(loc='center left', bbox_to_anchor=(1.0, 0.5),ncol = 4)
show()

# %%
from pandas.plotting import parallel_coordinates
figure()
parallel_coordinates(df, 'Names')
legend(loc='center left', bbox_to_anchor=(1.0, 0.5),ncol = 4)
show()

# %%
radviz(df[df.columns[:4]], 'Names')
legend([])
show()

# %%
radviz(df[['FlxIn','Eiity','Paank','Names']], 'Names')
legend([])
show()

# %%
radviz(df[['FlOut','Eiity','Paank','Names']], 'Names')
legend([])
show()

# %%
d = []
for i in df.columns[1:]:
    b=df[i]
    b=b.sort_values(ascending=False)
    c = list(b.iloc[:10].index)
    d.extend(c)
    print i, c

print ''
print  'reoccuring', set(d)

print ''
print 'repeats', (len(d) - len(set(d)))/float(len(d))*100,'%'
# Out:
# Fllux ['CH3CO3', 'PAN', 'HOCH2CO3', 'PHAN', 'CH3O2', 'CH3OOH', 'CH3CO3H', 'HOCH2CO3H', 'HCHO', 'CO']
# FlxIn ['CH3CO3', 'PAN', 'CH3CO3H', 'PHAN', 'HOCH2CO3', 'CH3OOH', 'HOCH2CO3H', 'CH3O2', 'CO', 'HCHO']
# FlOut ['CH3CO3', 'PAN', 'HOCH2CO3', 'CH3O2', 'PHAN', 'CH3OOH', 'HCHO', 'CH3CHO', 'C2H6', 'C2H5O2']
# Cless ['C2H5OH', 'HOCH2CH2O2', 'HOCH2CHO', 'HCHO', 'CH3CHO', 'C2H5NO3', 'CH3NO3', 'HOCH2CO3', 'C2H5O2', 'C2H5CHO']
# Eiity ['PAN', 'CH3CO3', 'CH3CO3H', 'CH3O2', 'CH3OOH', 'CO', 'HCHO', 'CH3OH', 'CH3NO3', 'C2H6']
# Paank ['CH3O2', 'CH3OOH', 'CH3CO3', 'PAN', 'CO', 'HCHO', 'C2H5CO3', 'PPN', 'CH3CO3H', 'CH3CHO']
# Beess ['C2H5OH', 'CH3O2', 'C2H5O2', 'CH3CHO', 'CH3CO3', 'CH3COCH3', 'HOCH2CH2O2', 'HOCH2CHO', 'IPROPOL', 'C2H5CO3']
# Auies ['HCHO', 'CO', 'CH3CO3', 'CH3O2', 'HOCH2CO3', 'CH3NO3', 'CH3OH', 'CH3OOH', 'PHAN', 'HOCH2CO3H']
# Huubs ['CH3CO3', 'CH3OOH', 'CH3CO3H', 'CH3COCH3', 'CH3CHO', 'PAN', 'HOCH2CO3', 'HOCH2CHO', 'HOCH2CO3H', 'CH3O2']
#
# reoccuring set(['HCHO', 'HOCH2CHO', 'C2H5CHO', 'CH3NO3', 'C2H5O2', 'CH3OH', 'PAN', 'IPROPOL', 'PPN', 'PHAN', 'C2H5CO3', 'CH3COCH3', 'CO', 'HOCH2CO3', 'HOCH2CH2O2', 'CH3CO3', 'C2H6', 'CH3CHO', 'HOCH2CO3H', 'CH3O2', 'C2H5NO3', 'C2H5OH', 'CH3OOH', 'CH3CO3H'])
#
# repeats 73.3333333333 %
